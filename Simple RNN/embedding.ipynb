# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
# sentences
sent = ['the glass of milk',
        'the glass of juice',
        'the cup of tea',
        'I am a good boy',
        'I am a good developer',
        'understand the meaning of words',
        'your videos are good']

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
# define vocabulary size
voc_size = 10000

# %%
# ohe representation 
one_hot_rep = [one_hot(words, voc_size) for words in sent]

# %%
one_hot_rep
# Out:
# [[5243, 7431, 8086, 660],
#  [5243, 7431, 8086, 9436],
#  [5243, 8494, 8086, 698],
#  [8304, 8231, 2854, 5662, 2177],
#  [8304, 8231, 2854, 5662, 3200],
#  [9884, 5243, 4073, 8086, 3610],
#  [2485, 5181, 6308, 5662]]

# %%
#  word embedding representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length = 8
embedded_docs = pad_sequences(one_hot_rep, padding='pre', maxlen=sent_length)

# %%
embedded_docs
# Out:
# array([[   0,    0,    0,    0, 5243, 7431, 8086,  660],
#        [   0,    0,    0,    0, 5243, 7431, 8086, 9436],
#        [   0,    0,    0,    0, 5243, 8494, 8086,  698],
#        [   0,    0,    0, 8304, 8231, 2854, 5662, 2177],
#        [   0,    0,    0, 8304, 8231, 2854, 5662, 3200],
#        [   0,    0,    0, 9884, 5243, 4073, 8086, 3610],
#        [   0,    0,    0,    0, 2485, 5181, 6308, 5662]], dtype=int32)

# %%
# feature representation
dim = 10

# %%
model = Sequential()
model.add(Embedding(voc_size, dim, input_length=sent_length))

model.compile(optimizer='adam', loss='mse')

# %%
output = model.predict(embedded_docs)
print(output.shape)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# (7, 8, 10)

# %%
output[0][0]
# Out:
# array([-0.04752952, -0.00586078,  0.01200796, -0.00850878,  0.02858833,
#         0.01830826,  0.0447777 , -0.03490548,  0.02293171, -0.0276026 ],
#       dtype=float32)
