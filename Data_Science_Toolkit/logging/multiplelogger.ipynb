# %% [markdown]
# # Logging with multiple loggers

# %%
import logging
#create a logger for module1
logger1 = logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)


#create a logger for module2
logger2 = logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
    force=True
)

# %%
#log messages from different loggers
logger1.debug("This is a debug message from module1")
logger2.warning("this is a warning message from module2")
logger2.error("This is a error message")
# Out:
# 2026-01-04 16:29:46-module1-DEBUG-This is a debug message from module1
# 2026-01-04 16:29:46-module2-WARNING-this is a warning message from module2
# 2026-01-04 16:29:46-module2-ERROR-This is a error message
