# %% [markdown]
# ## Simple Linear Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# Read the dataset
df=pd.read_csv('height-weight.csv')
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
plt.scatter(df['Weight'],df['Height'])
plt.xlabel("Weight")
plt.ylabel("Height")
# Out:
# Text(0, 0.5, 'Height')

# %%
# independent and dependent features
X=df[['Weight']] 
y=df['Height']

# %%
# Train test split
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
X.shape
# Out:
# (23, 1)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((18, 1), (5, 1), (18,), (5,))

# %%
# standardize the dataset Train independent data
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train.head()
# Out:
#     Weight
# 12     105
# 1       58
# 13     100
# 5       78
# 2       48

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
plt.scatter(X_train,y_train)

# %%
# Train the Simple Linear Regression Model
from sklearn.linear_model import LinearRegression

# %%
regressor=LinearRegression()

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print("The slope or coefficient of weight is ",regressor.coef_)
print("Intercept:",regressor.intercept_)
# Out:
# The slope or coefficient of weight is  [17.03440872]
# Intercept: 157.5

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train,regressor.predict(X_train),'r')
plt.show()

# %% [markdown]
# #### Prediction of train data
#     1. predicted height output = intercept + coef_(Weights)
#     2. y_pred_train = 157.5 + 17.03(X_train)
#
# #### Prediction of test data
#     1. predicted height output = intercept + coef_(Weights)
#     2. y_pred_test = 157.5 + 17.03(X_test)

# %%
y_pred_test = regressor.predict(X_test)

# %%
y_pred_test, y_test
# Out:
# (array([161.08467086, 161.08467086, 129.3041561 , 177.45645118,
#         148.56507414]),
#  15    177
#  9     170
#  0     120
#  8     182
#  17    159
#  Name: Height, dtype: int64)

# %%
plt.scatter(X_test,y_test)
plt.plot(X_test,regressor.predict(X_test),'r')
plt.show()

# %%
# Performance metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error

mse = mean_squared_error(y_test, y_pred_test)
mae = mean_absolute_error(y_test, y_pred_test)
rmse = np.sqrt(mse)

print(f'Mean sqaured error : {mse}')
print(f'Mean absolute error : {mae}')
print(f'Root mean sqaured error : {rmse}')
# Out:
# Mean sqaured error : 109.77592599051654
# Mean absolute error : 9.822657814519227
# Root mean sqaured error : 10.477400726827076

# %%
# R2 score
'''
R^2 = 1 - SSR / SST 
'''
from sklearn.metrics import r2_score
score = r2_score(y_test, y_pred_test)
print(score)
# Out:
# 0.7769869860423441

# %%
# Adjusted R sqaure
'''
1 - [(1-R2)*(n-1)/(n-k-1)]
'''
1 - (1 - score) * (len(y_test) - 1) / (len(y_test) - X_test.shape[1] - 1)
# Out:
# 0.7026493147231254

# %%
# new data point - weight is 80
scaled_weight = scaler.transform([[80]])
# Out:
# c:\Users\jenis\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
print("The height prediction for weight 80 kg is :",regressor.predict([scaled_weight[0]]))
# Out:
# The height prediction for weight 80 kg is : [163.01076266]

# %% [markdown]
# #### Assumptions

# %%
# scatter plot for prediction
plt.scatter(y_test, y_pred_test)
plt.show()

# %%
# residuals 
residuals = y_test - y_pred_test
residuals
# Out:
# 15    15.915329
# 9      8.915329
# 0     -9.304156
# 8      4.543549
# 17    10.434926
# Name: Height, dtype: float64

# %%
## plot this residuals
import seaborn as sns
sns.distplot(residuals,kde=True)
plt.show()
# Out:
# C:\Users\jenis\AppData\Local\Temp\ipykernel_21192\1454134060.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals,kde=True)

# %%
# scatter plot with respect to predictions and residuals
# uniform distribtuion
plt.scatter(y_pred_test, residuals)
plt.show()
